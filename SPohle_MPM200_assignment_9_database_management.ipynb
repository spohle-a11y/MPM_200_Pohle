# %% [markdown]
# <a href="https://colab.research.google.com/github/spohle-a11y/MPM_200_Pohle/blob/main/SPohle_MPM200_assignment_9_database_management.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Packages and Scientific Computing Libraries
#
# """
# Python Packages Overview:
# -------------------------
# Packages in Python are collections of modules that provide reusable code and functionality.
# They allow developers to organize and share complex code libraries that can be easily imported
# and used across different projects.
#
# Key Characteristics of Packages:
# - Organized hierarchically
# - Contain multiple related modules
# - Can be installed using package managers like pip
# - Extend Python's core functionality
#
# Three Essential Data Science Libraries:
# --------------------------------------
# 1. Pandas (pd):
#    - Primary library for data manipulation and analysis
#    - Provides DataFrame: a 2D labeled data structure with columns of potentially different types
#    - Key Features:
#      * Reading/writing data from various sources (CSV, Excel, SQL databases)
#      * Data cleaning and preprocessing
#      * Complex data transformations
#      * Powerful data analysis and aggregation tools
#
# 2. NumPy (np):
#    - Fundamental package for scientific computing in Python
#    - Introduces the ndarray (n-dimensional array) for efficient numerical operations
#    - Key Features:
#      * High-performance multidimensional array object
#      * Mathematical and statistical functions
#      * Linear algebra operations
#      * Foundation for scientific and numerical computing
#      * Enables fast computations on large datasets
#
# 3. Matplotlib (plt):
#    - Comprehensive library for creating static, animated, and interactive visualizations
#    - Provides MATLAB-like plotting interface
#    - Key Features:
#      * Line plots, scatter plots, bar charts, histograms
#      * Customizable plot styles and layouts
#      * Support for multiple plot types and graph formats
#      * Integration with NumPy for data visualization
#
# Practical Significance:
# ----------------------
# These libraries form the backbone of data science and scientific computing in Python,
# enabling complex data analysis, numerical computations, and insightful visualizations
# with minimal code.
# """

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Read the Excel file
df = pd.read_excel("/content/Flavivirus host associations.xlsx")

# Display basic information about the dataset
print(df.info())

# Show the first few rows of the data
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sr no.                  570 non-null    int64
#  1   Virus                   570 non-null    object
#  2   Scientific Name         570 non-null    object
#  3   Authors                 570 non-null    object
#  4   Year                    430 non-null    object
#  5   Title/accession number  570 non-null    object
#  6   Journal                 425 non-null    object
#  7   Issue                   415 non-null    float64
#  8   Volume                  404 non-null    object
#  9   Pages                   404 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 44.7+ KB
# None
#    sr no.         Virus     Scientific Name  \
# 0       3    Apoi virus       Rattus rattus
# 1       2    Apoi virus    Myodes rufocanus
# ...

# %% [markdown]
# ## Using pandas functions that you have seen in the class address following questions
# 1. How many entries are there in the dataset?
# 2. How many viruses are present in the dataset?
# 3. List those viruses.
# 4. How many rows of data are present for each virus?
# 5. How many host species are present in the data?
# 6. Make a list of host species present.
# 7. Count the number of unique host species for each virus.
# 8. Which virus has the most number of hosts?
# 9. Which host has most number of viruses?

# %%
# Exploring Virus and Species Diversity in the Dataset

# Count total number of entries in the dataset
570
# Count unique viruses
30
# List of unique viruses
see below
# Count of each unique virus
see below
# Count unique host species
419
# List of unique host species
see below
# Count of host species for each virus
see below
# Most diverse viruses (viruses with most unique host species)
West Nile virus

# %%
# 1. How many entries are there in the dataset?
print(f"Total entries in the dataset: {len(df)}")

# 2. How many viruses are present in the dataset?
num_viruses = df['Virus'].nunique()
print(f"Number of viruses present: {num_viruses}")

# 3. List those viruses.
list_of_viruses = df['Virus'].unique().tolist()
print(f"List of viruses: {list_of_viruses}")

# 4. How many rows of data are present for each virus?
print("\nNumber of rows per virus:")
print(df['Virus'].value_counts())

# 5. How many host species are present in the data?
num_host_species = df['Scientific Name'].nunique()
print(f"\nNumber of host species present: {num_host_species}")

# 6. Make a list of host species present.
list_of_host_species = df['Scientific Name'].unique().tolist()
print(f"\nList of host species: {list_of_host_species}")

# 7. Count the number of unique host species for each virus.
unique_hosts_per_virus = df.groupby('Virus')['Scientific Name'].nunique()
print("\nNumber of unique host species per virus:")
print(unique_hosts_per_virus)

# 8. Which virus has the most number of hosts?
most_diverse_virus = unique_hosts_per_virus.idxmax()
print(f"\nVirus with the most unique host species: {most_diverse_virus} ({unique_hosts_per_virus.max()} hosts)")

# 9. Which host has most number of viruses?
host_viruses_count = df.groupby('Scientific Name')['Virus'].nunique()
most_versatile_host = host_viruses_count.idxmax()
print(f"\nHost species associated with the most viruses: {most_versatile_host} ({host_viruses_count.max()} viruses)")
# Out:
# Total entries in the dataset: 570
# Number of viruses present: 30
# List of viruses: ['Apoi virus', 'Bagaza virus', 'Banzi virus', 'Bouboui virus', 'Bussuquara virus', 'Cacipacore virus', 'Dakar bat virus', 'Dengue virus', 'Entebbe bat virus', 'Iguape virus', 'Ilheus virus', 'Japanese encephalitis virus', 'Koutango virus', 'Kunjin virus', 'Kyasanur forest virus', 'Louping-ill virus', 'Modoc virus', 'Murray Valley encephalitis virus', 'Omsk hemorrhagic fever virus', 'Rio Bravo virus', 'Rocio virus', 'St. Louis Encephalitis virus', 'Tembusu virus', 'Tickborne encephalitis virus', 'Uganda S virus', 'Usutu virus', 'Wesselsbron virus', 'West Nile virus', 'Yellow fever virus', 'Zika virus']
#
# Number of rows per virus:
# Virus
# West Nile virus                     194
# Tickborne encephalitis virus         84
# St. Louis Encephalitis virus         72
# Usutu virus                          65
# Dengue virus                         27
# Japanese encephalitis virus          25
# ...

# %% [markdown]
# # Metadata
#
# ## Given that we are interested in the metadata associated with these host species, we will import datasets associated with the metadata for both bird and mammalian species.

# %% [markdown]
# 1. Birds

# %%
loc = "/content/Handbook of the Birds of the World and BirdLife International Digital Checklist of the Birds of the World_Version_9 (1).xlsx"
birds_meta = pd.read_excel(loc)
birds_meta.head()
# Out:
#    Seq.  Subsp. Seq.             Order    Family name     Family Subfamily  \
# 0   1.0          0.0  STRUTHIONIFORMES  Struthionidae  Ostriches       NaN
# 1   1.0          1.0               NaN            NaN        NaN       NaN
# 2   1.0          2.0               NaN            NaN        NaN       NaN
# 3   1.0          3.0               NaN            NaN        NaN       NaN
# 4   1.0          4.0               NaN            NaN        NaN       NaN
#
#   Tribe     Common name             Scientific name       Authority  \
# 0   NaN  Common Ostrich            Struthio camelus  Linnaeus, 1758
# 1   NaN             NaN   Struthio camelus syriacus             NaN
# 2   NaN             NaN    Struthio camelus camelus             NaN
# 3   NaN             NaN  Struthio camelus massaicus             NaN
# 4   NaN             NaN  Struthio camelus australis             NaN
#
#   2024 IUCN Red List category Synonyms Alternative common names  \
# ...

# %% [markdown]
# The data for birds is at subspecies level. It means that there is species name represented by column `Seq.`. All rows in same number represent one species.

# %% [markdown]
# 2. Mammals

# %% [markdown]
# ## Similarly, read file for mammals metadata.

# %%
loc = "/content/IUCN Mammals, Birds, Reptiles, and Amphibians.csv"
mammals_meta = pd.read_csv(loc, encoding='latin-1')
mammals_meta.head()
# Out:
#    Species ID   Kingdom    Phylum     Class             Order       Family  \
# 0     42641.0  ANIMALIA  CHORDATA  MAMMALIA          RODENTIA      MURIDAE
# 1  22687170.0  ANIMALIA  CHORDATA      AVES  CAPRIMULGIFORMES  TROCHILIDAE
# 2     17879.0  ANIMALIA  CHORDATA  MAMMALIA          RODENTIA      MURIDAE
# 3  47760825.0  ANIMALIA  CHORDATA  MAMMALIA          RODENTIA   CRICETIDAE
# 4     42656.0  ANIMALIA  CHORDATA  MAMMALIA          RODENTIA  ABROCOMIDAE
#
#           Genus    Species                  Authority  Infraspecific rank  \
# 0     Abditomys   latidens            (Sanborn, 1952)                 NaN
# 1      Abeillia   abeillei  (Lesson & DeLattre, 1839)                 NaN
# 2   Abeomelomys      sevia    (Tate & Archbold, 1935)                 NaN
# 3  Abrawayaomys    ruschii         Cunha & Cruz, 1979                 NaN
# 4      Abrocoma  bennettii           Waterhouse, 1837                 NaN
#
#    ...                             Synonyms  \
# ...

# %% [markdown]
# ## QUESTION For both birds and mammals answer the following questions.
# 1. Size of the datasets
# 2. For birds, filter the dataset using species-level rows only. Hint. Column `Subsp. Seq.` value of 0 indicates the main species name
# 3. How many bird species and mammal species are present in data frames?

# %% [markdown]
# 1. Shape of birds_meta DataFrame: (33265 rows, 17 columns)
# Shape of mammals_meta DataFrame: (16081 rows, 23 columns)
# 2. 5 rows
# 3. Number of unique bird species: 11198
# Number of unique mammal species: 8779

# %%
display(birds_species_only.head())

# %% [markdown]
# # Database Integration Exercise
# The main objective of this exercise is to create a comprehensive database by combining three data frames. Follow these steps  n your analysis.

# %% [markdown]
# ## Create a concept map:
# * Illustrate the relationships between the three data frames.
# * Identify and highlight the Primary Keys in each data frame.
# * Use a diagramming tool (e.g., PowerPoint, LucidChart, or Draw.io) to create a visual representation of these connections.
# * Pay special attention to how you plan to merge the Mammals and Birds data frames.

# %%
from IPython.display import Image, display

# Path to the screenshot file
screenshot_path = "/content/Screenshot 2025-12-09 at 1.55.27\u202fPM.png"

# Display the screenshot
print("Displaying the screenshot:")
display(Image(filename=screenshot_path))
# Out:
# Displaying the screenshot:

# %% [markdown]
# ## Perform a vertical join of Mammals and Birds data frames:
# * Identify and select only the common columns present in both data frames.
# * Use `pd.concat()` or `df.append()` to create a larger dataframe called **metadata**.
# * Ensure the resulting dataframe has the correct number of rows and columns.

# %% [markdown]
# ## Merge the metadata dataframe with the Flavivirus dataframe:
# * Experiment with different join types: `inner`, `outer`, `left`, and `right`.
# * For each join type, record the resulting dataframe's shape (rows and columns).
# * Determine the **theoretically correct size of the merged dataframe if done manually**.
# * Compare the results of each join type with the expected outcome.
# * Choose the most appropriate join type based on your analysis.

# %% [markdown]
# ### Create a pivote table,
# 1. Rows are virueses
# 2. Columns are Taxonomic orders
# 3. Values are number of unique host species

# %% [markdown]
# # Task
# Calculate and print the number of rows and columns for the `birds_meta` and `mammals_meta` dataframes. Filter the `birds_meta` dataframe to include only species-level entries (where the `Subsp. Seq.` column is 0), storing this in a new dataframe named `birds_species_only`. Then, count and print the number of unique bird species from `birds_species_only` using the 'Scientific name' column and unique mammal species from `mammals_meta` using the 'Species' column.

# %% [markdown]
# ## Analyze Dataset Sizes
#
# ### Subtask:
# Determine and print the number of rows and columns for both the `birds_meta` and `mammals_meta` dataframes to understand their initial sizes.

# %% [markdown]
# **Reasoning**:
# To understand the initial sizes of the `birds_meta` and `mammals_meta` dataframes, I will print their shapes, which provide the number of rows and columns.

# %%
print(f"Shape of birds_meta DataFrame: {birds_meta.shape}")
print(f"Shape of mammals_meta DataFrame: {mammals_meta.shape}")
# Out:
# Shape of birds_meta DataFrame: (33265, 17)
# Shape of mammals_meta DataFrame: (16081, 23)

# %% [markdown]
# **Reasoning**:
# I will filter the `birds_meta` dataframe to include only species-level entries, where the 'Subsp. Seq.' column is 0, and then count the number of unique bird species from this filtered dataframe and unique mammal species from the `mammals_meta` dataframe, as per the subtask instructions.

# %%
birds_species_only = birds_meta[birds_meta['Subsp. Seq.'] == 0]
print(f"Number of unique bird species: {birds_species_only['Scientific name'].nunique()}")
print(f"Number of unique mammal species: {mammals_meta['Species'].nunique()}")
# Out:
# Number of unique bird species: 11198
# Number of unique mammal species: 8779

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Present a summary of the dataset sizes for birds and mammals, and the total counts of bird and mammal species after filtering the bird data.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# *   The `birds_meta` dataset contains `33265` rows and `17` columns, while the `mammals_meta` dataset contains `16081` rows and `23` columns.
# *   After filtering the bird data, there are `11198` unique bird species and `8779` unique mammal species.
#
# ### Data Analysis Key Findings
# *   The initial `birds_meta` DataFrame is significantly larger than `mammals_meta` in terms of rows, with `33265` rows compared to `16081` rows.
# *   After filtering `birds_meta` to include only species-level entries (where 'Subsp. Seq.' is 0), `11198` unique bird species were identified.
# *   The `mammals_meta` DataFrame contains `8779` unique mammal species.

# %% [markdown]
# # Task
# Describe the structure and identify primary keys for the `df` (Flavivirus host associations), `birds_meta`, and `mammals_meta` dataframes. Then, explain the process of vertically joining the `mammals_meta` and `birds_meta` dataframes into a unified `metadata` dataframe, including how common columns will be handled. Finally, describe how this `metadata` dataframe will be merged with the `df` (Flavivirus) dataframe, specifying the join key.

# %% [markdown]
# ## Describe Dataframes and Primary Keys
#
# ### Subtask:
# Outline the structure and identify the primary keys for each of the three dataframes: `df` (Flavivirus host associations), `birds_meta`, and `mammals_meta`.

# %% [markdown]
# **Reasoning**:
# To understand the structure and data types of the `df` dataframe and identify a potential primary key, I will display its information using `.info()` and the first few rows using `.head()`.

# %%
print("--- df (Flavivirus host associations) ---")
df.info()
display(df.head())
# Out:
# --- df (Flavivirus host associations) ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sr no.                  570 non-null    int64
#  1   Virus                   570 non-null    object
#  2   Scientific Name         570 non-null    object
#  3   Authors                 570 non-null    object
#  4   Year                    430 non-null    object
#  5   Title/accession number  570 non-null    object
#  6   Journal                 425 non-null    object
#  7   Issue                   415 non-null    float64
#  8   Volume                  404 non-null    object
#  9   Pages                   404 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 44.7+ KB
#    sr no.         Virus     Scientific Name  \
# 0       3    Apoi virus       Rattus rattus
# ...

# %% [markdown]
# **Reasoning**:
# To understand the structure and data types of the `birds_meta` dataframe and identify a potential primary key, I will display its information using `.info()` and the first few rows using `.head()`. I will also specifically display the first 5 rows of the `birds_species_only` dataframe, which has been pre-filtered to include only species-level entries (where 'Subsp. Seq.' is 0), as this is relevant for identifying a primary key at the species level.

# %%
print("--- birds_meta ---")
birds_meta.info()
display(birds_meta.head())
print("\n--- birds_species_only (first 5 rows) ---")
display(birds_species_only.head())
# Out:
# --- birds_meta ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33265 entries, 0 to 33264
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Seq.                             33252 non-null  float64
#  1   Subsp. Seq.                      31224 non-null  float64
#  2   Order                            13233 non-null  object
#  3   Family name                      13232 non-null  object
#  4   Family                           13232 non-null  object
#  5   Subfamily                        8123 non-null   object
#  6   Tribe                            3583 non-null   object
#  7   Common name                      11195 non-null  object
#  8   Scientific name                  33252 non-null  object
#  9   Authority                        13232 non-null  object
#  10  2024 IUCN Red List category      13232 non-null  object
# ...

# %% [markdown]
# **Reasoning**:
# To understand the structure and data types of the `mammals_meta` dataframe and identify a potential primary key, I will display its information using `.info()` and the first few rows using `.head()`.

# %%
print("--- mammals_meta ---")
mammals_meta.info()
display(mammals_meta.head())
# Out:
# --- mammals_meta ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16081 entries, 0 to 16080
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Species ID                 15961 non-null  float64
#  1   Kingdom                    16081 non-null  object
#  2   Phylum                     16081 non-null  object
#  3   Class                      16081 non-null  object
#  4   Order                      16081 non-null  object
#  5   Family                     16081 non-null  object
#  6   Genus                      16081 non-null  object
#  7   Species                    16077 non-null  object
#  8   Authority                  15955 non-null  object
#  9   Infraspecific rank         0 non-null      float64
#  10  Infraspecific name         0 non-null      float64
#  11  Infraspecific authority    0 non-null      float64
#  12  Stock/subpopulation        0 non-null      float64
# ...

# %% [markdown]
# ## Summary of Dataframe Structures and Primary Keys
#
# ### 1. `df` (Flavivirus host associations)
# *   **Main Columns**: `sr no.`, `Virus`, `Scientific Name`, `Authors`, `Year`, `Title/accession number`, `Journal`, `Issue`, `Volume`, `Pages`.
# *   **Data Types**: `sr no.` (int64), `Issue` (float64), others are `object` (strings).
# *   **Primary Key Identification**: The column `sr no.` seems to be a unique identifier, but given that it starts from 0 and has non-sequential values (e.g., 3, 2, 0, 1, 4 in the head), it's more likely an entry sequence rather than a unique ID that is guaranteed to be contiguous or globally unique. A combination of `Virus` and `Scientific Name` *might* uniquely identify a host association, but there could be multiple records for the same virus-host pair if they represent different studies or observations. For this dataset, `sr no.` could serve as a unique identifier for each *record* as it is an integer and non-null for all entries, but for identifying *unique biological associations*, a composite key like (`Virus`, `Scientific Name`) might be more appropriate depending on the analytical goal. For the purpose of merging with metadata, 'Scientific Name' is the crucial column for joining.
#
# ### 2. `birds_meta` (Bird Metadata)
# *   **Main Columns**: `Seq.`, `Subsp. Seq.`, `Order`, `Family name`, `Family`, `Common name`, `Scientific name`, `Authority`, `2024 IUCN Red List category`, `SISRecID`.
# *   **Data Types**: `Seq.`, `Subsp. Seq.`, `SISRecID` (float64), others are `object` (strings).
# *   **Primary Key Identification**: For the raw `birds_meta` dataframe, `SISRecID` (or `SpcRecID`) appears to be a unique identifier for each taxonomic entry (species or subspecies). The instructions mention that `Seq.` with `Subsp. Seq.` of `0` represents a main species. Therefore, in the filtered `birds_species_only` dataframe, `SISRecID` or a combination of `Seq.` and `Scientific name` would serve as a primary key for unique bird species. The `Scientific name` column will be used for joining with the `df` dataframe.
#
# ### 3. `mammals_meta` (Mammal Metadata)
# *   **Main Columns**: `Species ID`, `Kingdom`, `Phylum`, `Class`, `Order`, `Family`, `Genus`, `Species`, `Authority`, `Common names (Eng)`, `Red List status`, `Year assessed`.
# *   **Data Types**: `Species ID`, `Infraspecific rank/name/authority`, `Red List criteria version`, `Year assessed` (float64), others are `object` (strings).
# *   **Primary Key Identification**: `Species ID` is clearly designed as a unique identifier for each mammal species. The `Species` column (which is the scientific name) will be used for joining with the `df` dataframe.

# %% [markdown]
# ## Summary of Dataframe Structures and Primary Keys
#
# ### 1. `df` (Flavivirus host associations)
# *   **Main Columns**: `sr no.`, `Virus`, `Scientific Name`, `Authors`, `Year`, `Title/accession number`, `Journal`, `Issue`, `Volume`, `Pages`.
# *   **Data Types**: `sr no.` (int64), `Issue` (float64), others are `object` (strings).
# *   **Primary Key Identification**: The column `sr no.` seems to be a unique identifier, but given that it starts from 0 and has non-sequential values (e.g., 3, 2, 0, 1, 4 in the head), it's more likely an entry sequence rather than a unique ID that is guaranteed to be contiguous or globally unique. A combination of `Virus` and `Scientific Name` *might* uniquely identify a host association, but there could be multiple records for the same virus-host pair if they represent different studies or observations. For this dataset, `sr no.` could serve as a unique identifier for each *record* as it is an integer and non-null for all entries, but for identifying *unique biological associations*, a composite key like (`Virus`, `Scientific Name`) might be more appropriate depending on the analytical goal. For the purpose of merging with metadata, 'Scientific Name' is the crucial column for joining.
#
# ### 2. `birds_meta` (Bird Metadata)
# *   **Main Columns**: `Seq.`, `Subsp. Seq.`, `Order`, `Family name`, `Family`, `Common name`, `Scientific name`, `Authority`, `2024 IUCN Red List category`, `SISRecID`.
# *   **Data Types**: `Seq.`, `Subsp. Seq.`, `SISRecID` (float64), others are `object` (strings).
# *   **Primary Key Identification**: For the raw `birds_meta` dataframe, `SISRecID` (or `SpcRecID`) appears to be a unique identifier for each taxonomic entry (species or subspecies). The instructions mention that `Seq.` with `Subsp. Seq.` of `0` represents a main species. Therefore, in the filtered `birds_species_only` dataframe, `SISRecID` or a combination of `Seq.` and `Scientific name` would serve as a primary key for unique bird species. The `Scientific name` column will be used for joining with the `df` dataframe.
#
# ### 3. `mammals_meta` (Mammal Metadata)
# *   **Main Columns**: `Species ID`, `Kingdom`, `Phylum`, `Class`, `Order`, `Family`, `Genus`, `Species`, `Authority`, `Common names (Eng)`, `Red List status`, `Year assessed`.
# *   **Data Types**: `Species ID`, `Infraspecific rank/name/authority`, `Red List criteria version`, `Year assessed` (float64), others are `object` (strings).
# *   **Primary Key Identification**: `Species ID` is clearly designed as a unique identifier for each mammal species. The `Species` column (which is the scientific name) will be used for joining with the `df` dataframe.

# %% [markdown]
# ## Detail Vertical Join of Mammals and Birds
#
# ### Subtask:
# Explain the process of vertically joining the `mammals_meta` and `birds_meta` dataframes to create a unified `metadata` dataframe. This includes identifying common columns and the method for concatenation.

# %% [markdown]
# **Reasoning**:
# To prepare for the vertical join, I will first identify and print the common column names between `birds_species_only` and `mammals_meta` to understand which fields will be preserved in the unified `metadata` dataframe.

# %%
common_cols = list(set(birds_species_only.columns) & set(mammals_meta.columns))
print(f"Common columns between birds_species_only and mammals_meta: {common_cols}")
# Out:
# Common columns between birds_species_only and mammals_meta: ['Authority', 'Synonyms', 'Order', 'Family']

# %% [markdown]
# **Reasoning**:
# Now that common columns are identified, I will select these columns from both `birds_species_only` and `mammals_meta` to create new dataframes, and then vertically concatenate them to form the `metadata` dataframe as instructed.

# %%
birds_common_cols = birds_species_only[common_cols]
mammals_common_cols = mammals_meta[common_cols]

metadata = pd.concat([birds_common_cols, mammals_common_cols], ignore_index=True)

print("First few rows of the unified metadata dataframe:")
display(metadata.head())
print(f"Shape of the unified metadata dataframe: {metadata.shape}")
# Out:
# First few rows of the unified metadata dataframe:
#            Authority Synonyms             Order     Family
# 0     Linnaeus, 1758      NaN  STRUTHIONIFORMES  Ostriches
# 1    Reichenow, 1883      NaN  STRUTHIONIFORMES  Ostriches
# 2   (Linnaeus, 1758)      NaN  STRUTHIONIFORMES      Rheas
# 3    d'Orbigny, 1834      NaN  STRUTHIONIFORMES      Rheas
# 4  (Bonaparte, 1854)      NaN  STRUTHIONIFORMES   Tinamous
# Shape of the unified metadata dataframe: (27285, 4)

# %% [markdown]
# ### Vertical Join of Mammals and Birds Dataframes
#
# To create a unified `metadata` dataframe from `birds_meta` and `mammals_meta`, we followed these steps:
#
# 1.  **Identify Common Columns**: We first determined the intersection of column names between the `birds_species_only` (which is a filtered version of `birds_meta` containing only species-level entries) and `mammals_meta` dataframes. This step ensures that only relevant and comparable fields are retained during the concatenation.
#
#     The common columns identified were: `['Synonyms', 'Family', 'Order', 'Authority']`.
#
# 2.  **Select Common Columns**: From both `birds_species_only` and `mammals_meta`, we selected only these common columns to create two temporary dataframes: `birds_common_cols` and `mammals_common_cols`.
#
# 3.  **Vertical Concatenation**: These two temporary dataframes (`birds_common_cols` and `mammals_common_cols`) were then vertically concatenated using `pd.concat()`. The `ignore_index=True` parameter was used to reset the index of the resulting `metadata` dataframe, ensuring a continuous index across all rows from both original dataframes.
#
#     The resulting `metadata` dataframe contains all rows from both the bird and mammal species datasets, but only for the columns that were common to both. This creates a consolidated table of taxonomic metadata for both groups, ready for further integration with the Flavivirus host association data.

# %% [markdown]
# ## Describe Merge of Metadata with Flavivirus Data
#
# ### Subtask:
# Explain how the combined `host_metadata` dataframe (containing scientific names and taxonomic information) will be merged with the `df` (Flavivirus) dataframe, focusing on the common column (`Scientific Name` or similar) that will serve as the join key. Experiment with different join types, record their resulting shapes, and determine the most appropriate join type.

# %% [markdown]
# ## Summary:
#
# ### Q&A
#
# 1.  **What are the structures and primary keys for `df`, `birds_meta`, and `mammals_meta` dataframes?**
#     *   **`df` (Flavivirus host associations):** Contains 570 entries and 10 columns. `sr no.` serves as a unique record identifier, while `Scientific Name` is crucial for merging with metadata.
#     *   **`birds_meta` (Bird Metadata):** Contains 33,265 entries and 17 columns. `SISRecID` (or `SpcRecID`) is the unique identifier for each taxonomic entry (species/subspecies). For species-level entries, `Scientific name` will be used for joining.
#     *   **`mammals_meta` (Mammal Metadata):** Contains 16,081 entries and 23 columns. `Species ID` is the unique identifier for each mammal species, and the `Species` column (scientific name) will be used for joining.
#
# 2.  **How are `mammals_meta` and `birds_meta` vertically joined into a unified `metadata` dataframe?**
#     The `birds_meta` (specifically `birds_species_only`) and `mammals_meta` dataframes are vertically joined by first identifying their common columns: `['Synonyms', 'Family', 'Order', 'Authority']`. Only these common columns are selected from both dataframes, and then they are concatenated using `pd.concat()` with `ignore_index=True` to create a unified `metadata` dataframe.
#
# ### Data Analysis Key Findings
#
# *   The `df` (Flavivirus host associations) dataframe has 570 entries, with `sr no.` as a potential record identifier and `Scientific Name` identified as the key column for future merges.
# *   The `birds_meta` dataframe contains 33,265 entries, and `SISRecID` is identified as its primary key. The `Scientific name` column is designated for joining.
# *   The `mammals_meta` dataframe contains 16,081 entries, with `Species ID` as its primary key. The `Species` column is designated for joining.
# *   The common columns between the `birds_species_only` and `mammals_meta` dataframes, used for vertical concatenation, are `['Synonyms', 'Family', 'Order', 'Authority']`.
# *   The unified `metadata` dataframe, created by vertically joining the selected common columns from `birds_species_only` and `mammals_meta`, has a shape of (27285, 4).
#
# ### Insights or Next Steps
#
# *   The consolidated `metadata` dataframe, containing relevant taxonomic information for both birds and mammals, is now prepared for merging with the Flavivirus host association data.
# *   The next logical step is to perform the merge operation between the `df` (Flavivirus data) and the newly created `metadata` dataframe, using `Scientific Name` from `df` and the corresponding scientific name column from `metadata` as the join key. This will enrich the Flavivirus host data with comprehensive host taxonomic details.

# %% [markdown]
# # Task
# ## Prepare Metadata for Merging
#
# ### Subtask: Prepare the `birds_species_only` and `mammals_meta` dataframes for merging by selecting relevant columns, renaming them for consistency, and adding a 'Class' column to each. Then, vertically concatenate these prepared dataframes into a single `unified_metadata` dataframe.
#
# ### Reasoning:
# To achieve a unified metadata dataframe that can be merged with the Flavivirus host associations, I need to standardize the taxonomic information from both the bird and mammal datasets. This involves:
# 1.  Selecting the 'Scientific name' and 'Order' from `birds_species_only`, renaming 'Scientific name' to 'Scientific_Name', and adding a 'Class' column as 'AVES'.
# 2.  Selecting the 'Species' and 'Order' from `mammals_meta`, renaming 'Species' to 'Scientific_Name', and adding a 'Class' column as 'MAMMALIA'.
# 3.  Concatenating these two prepared dataframes vertically to create `unified_metadata` with consistent column names and taxonomic class identification.

# %% [markdown]
# ## Prepare Birds Metadata for Merging
#
# ### Subtask:
# Select the 'Scientific name' and 'Order' columns from `birds_species_only`, rename 'Scientific name' to 'Scientific_Name', and add a 'Class' column with the value 'AVES' to clearly identify bird entries.

# %% [markdown]
# **Reasoning**:
# To prepare the bird metadata, I will select the specified columns, rename 'Scientific name' to 'Scientific_Name', and add a 'Class' column with 'AVES', storing the result in `birds_prepared`.

# %%
birds_prepared = birds_species_only[['Scientific name', 'Order']].copy()
birds_prepared = birds_prepared.rename(columns={'Scientific name': 'Scientific_Name'})
birds_prepared['Class'] = 'AVES'

print("First few rows of the prepared bird metadata:")
display(birds_prepared.head())
# Out:
# First few rows of the prepared bird metadata:
#            Scientific_Name             Order Class
# 0         Struthio camelus  STRUTHIONIFORMES  AVES
# 5   Struthio molybdophanes  STRUTHIONIFORMES  AVES
# 6           Rhea americana  STRUTHIONIFORMES  AVES
# 12            Rhea pennata  STRUTHIONIFORMES  AVES
# 16      Nothocercus julius  STRUTHIONIFORMES  AVES

# %% [markdown]
# ## Prepare Mammals Metadata for Merging
#
# ### Subtask:
# Select the 'Species' and 'Order' columns from `mammals_meta`, rename 'Species' to 'Scientific_Name', and add a 'Class' column with the value 'MAMMALIA' to clearly identify mammal entries.

# %% [markdown]
# **Reasoning**:
# To prepare the mammal metadata for merging, I will select the specified columns, rename 'Species' to 'Scientific_Name', and add a 'Class' column with 'MAMMALIA', storing the result in `mammals_prepared`.

# %%
mammals_prepared = mammals_meta[['Species', 'Order']].copy()
mammals_prepared = mammals_prepared.rename(columns={'Species': 'Scientific_Name'})
mammals_prepared['Class'] = 'MAMMALIA'

print("First few rows of the prepared mammal metadata:")
display(mammals_prepared.head())
# Out:
# First few rows of the prepared mammal metadata:
#   Scientific_Name             Order     Class
# 0        latidens          RODENTIA  MAMMALIA
# 1        abeillei  CAPRIMULGIFORMES  MAMMALIA
# 2           sevia          RODENTIA  MAMMALIA
# 3         ruschii          RODENTIA  MAMMALIA
# 4       bennettii          RODENTIA  MAMMALIA

# %% [markdown]
# **Reasoning**:
# Now that both bird and mammal metadata have been prepared with consistent column names and a 'Class' identifier, I will vertically concatenate them to create a single `unified_metadata` dataframe, resetting the index for a clean result.

# %%
unified_metadata = pd.concat([birds_prepared, mammals_prepared], ignore_index=True)

print("First few rows of the unified metadata dataframe:")
display(unified_metadata.head())
print(f"Shape of the unified metadata dataframe: {unified_metadata.shape}")
# Out:
# First few rows of the unified metadata dataframe:
#           Scientific_Name             Order Class
# 0        Struthio camelus  STRUTHIONIFORMES  AVES
# 1  Struthio molybdophanes  STRUTHIONIFORMES  AVES
# 2          Rhea americana  STRUTHIONIFORMES  AVES
# 3            Rhea pennata  STRUTHIONIFORMES  AVES
# 4      Nothocercus julius  STRUTHIONIFORMES  AVES
# Shape of the unified metadata dataframe: (27285, 3)

# %% [markdown]
# ## Merge Flavivirus Data with Unified Metadata
#
# ### Subtask:
# Merge the `df` (Flavivirus host associations) dataframe with the `unified_metadata` dataframe on the 'Scientific Name' column to enrich the Flavivirus data with host taxonomic orders.

# %% [markdown]
# **Reasoning**:
# To enrich the Flavivirus data with taxonomic information, I will perform a left merge between the `df` dataframe and the `unified_metadata` dataframe using the specified 'Scientific Name' columns as keys. Then, I will display the first few rows and the shape of the resulting dataframe to verify the merge operation.

# %%
merged_df = pd.merge(df, unified_metadata, left_on='Scientific Name', right_on='Scientific_Name', how='left')

print("First few rows of the merged_df:")
display(merged_df.head())
print(f"Shape of the merged_df: {merged_df.shape}")
# Out:
# First few rows of the merged_df:
#    sr no.         Virus     Scientific Name  \
# 0       3    Apoi virus       Rattus rattus
# 1       2    Apoi virus    Myodes rufocanus
# 2       0    Apoi virus  Apodemus argenteus
# 3       1    Apoi virus  Apodemus speciosus
# 4       4  Bagaza virus      Alectoris rufa
#
#                                              Authors  Year  \
# 0  C. M. Baak-Baak, N. Cigarroa-Toledo, O. M. Tor...  2016
# 1                                        CDC Arbocat   NaN
# 2                 J. S. Mackenzie and D. T. Williams  2009
# 3                 J. S. Mackenzie and D. T. Williams  2009
# 4  D. Buitrago, A. Rocha, C. Tena-Tomas, M. Vigo,...  2012
#
#                               Title/accession number  \
# 0  New Records of Ectoparasites Echinolaelaps ech...
# 1                                        CDC Arbocat
# 2  The zoonotic flaviviruses of southern, south-e...
# 3  The zoonotic flaviviruses of southern, south-e...
# ...

# %% [markdown]
# ## Create Pivot Table of Viruses by Taxonomic Order
#
# ### Subtask:
# Construct a pivot table where rows represent viruses, columns represent taxonomic orders, and values show the count of unique host species for each virus-order combination.

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The `unified_metadata` dataframe, containing standardized scientific names, orders, and classes for both birds and mammals, was successfully created with 27,285 rows and 3 columns.
# *   The Flavivirus host associations dataframe was enriched by merging it with the `unified_metadata`, resulting in a `merged_df` with 570 rows and 13 columns.
# *   The merge operation revealed that some host species in the original Flavivirus data (`df`) did not have matching taxonomic information (Order, Class) in the `unified_metadata`, resulting in `NaN` values for these columns in the `merged_df`.
#
# ### Insights or Next Steps
#
# *   Investigate the host species in the `merged_df` that have `NaN` values for 'Order' and 'Class' to determine if their taxonomic information can be found from alternative sources or if they represent non-avian/mammalian hosts.
# *   Proceed with creating the pivot table of viruses by taxonomic order using the `merged_df`, leveraging the newly integrated 'Order' column for analysis.

# %% [markdown]
# # Task
# To fulfill the request of analyzing virus and host diversity, generate code to create a pivot table using the `merged_df` where:
# - Rows are 'Virus'.
# - Columns are 'Order' (taxonomic orders of host species).
# - Values are the count of unique 'Scientific Name' (host species) for each virus-order combination.
# Display the pivot table and its shape.

# %% [markdown]
# ## Analyze Virus and Host Diversity
#
# ### Subtask:
# Generate code to count total entries, unique viruses, list unique viruses, count occurrences of each virus, count unique host species, list unique host species, count host species per virus, and identify viruses with the most unique host species.

# %% [markdown]
# ## Summary:
#
# The solving process aimed to analyze virus and host diversity by constructing a pivot table. This table was designed to show viruses as rows and host taxonomic orders as columns, with the values representing the count of unique host species for each virus-order combination. The process intended to display this pivot table along with its shape.
#
# ### Data Analysis Key Findings
# The detailed results of the pivot table generation, including the pivot table itself and its shape, were not provided in the solving process. Therefore, no specific data analysis key findings can be reported at this time.
#
# ### Insights or Next Steps
# *   Once the pivot table is generated and displayed, it would allow for immediate identification of viruses that infect a wide range of host species across various taxonomic orders, or those that are highly specialized to specific host orders.
# *   The next step would be to analyze the resulting pivot table to identify viruses with the most diverse host ranges, specific associations with particular host orders, and to further quantify the patterns of virus-host interactions.

# %%
pivot_table_virus_host_diversity = merged_df.pivot_table(
    index='Virus',
    columns='Order',
    values='Scientific Name',
    aggfunc='nunique'
)

print("Pivot Table of Virus Host Diversity:")
display(pivot_table_virus_host_diversity)
print(f"Shape of the pivot table: {pivot_table_virus_host_diversity.shape}")
# Out:
# Pivot Table of Virus Host Diversity:
# Order                             ACCIPITRIFORMES  ANSERIFORMES  \
# Virus
# Bagaza virus                                  NaN           NaN
# Ilheus virus                                  NaN           NaN
# Japanese encephalitis virus                   NaN           NaN
# Koutango virus                                NaN           NaN
# Kunjin virus                                  NaN           NaN
# Louping-ill virus                             NaN           NaN
# Murray Valley encephalitis virus              NaN           NaN
# Rocio virus                                   NaN           NaN
# St. Louis Encephalitis virus                  1.0           NaN
# Tembusu virus                                 NaN           1.0
# Tickborne encephalitis virus                  1.0           7.0
# Uganda S virus                                NaN           NaN
# Usutu virus                                   4.0           NaN
# ...
